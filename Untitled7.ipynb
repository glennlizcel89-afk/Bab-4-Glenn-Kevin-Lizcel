# %% [markdown]
# <a href="https://colab.research.google.com/github/glennlizcel89-afk/Bab-4-Glenn-Kevin-Lizcel/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('halo, fahri')
# Out:
# halo, fahri
